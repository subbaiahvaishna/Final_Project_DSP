# %% [markdown]
# ### Vaishna Subbaiah
# #### 11/26/25
# ###### Final Project - Milestone #2

# %% [markdown]
# #### load the excel file and look at the first 20 rows

# %%
import pandas as pd

df_raw = pd.read_excel("SeriesReport-20251125214831_41ed41.xlsx")
df_raw.head(20)
# Out:
# C:\Users\Vaish\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#    Import/Export Price Indexes  \
# 0          Original Data Value
# 1                          NaN
# 2                   Series Id:
# 3                Series Title:
# 4                  Index Type:
# 5                        Item:
# 6                 Base Period:
# 7                       Years:
# 8                          NaN
# 9                         Year
# 10                        2015
# 11                        2016
# 12                        2017
# 13                        2018
# 14                        2019
# 15                        2020
# 16                        2021
# 17                        2022
# 18                        2023
# 19                        2024
#
# ...

# %% [markdown]
# #### load the excel file starting at row 11, then rearrange it so months are in one column

# %%
df = pd.read_excel(
    "SeriesReport-20251125214831_41ed41.xlsx",
    header=10   #change this number after checking df_raw.head()
)
df.head()


df = pd.read_excel("SeriesReport-20251125214831_41ed41.xlsx", header=10)

df_long = df.melt(id_vars=["Year"],
                  var_name="Month",
                  value_name="Value")
# Out:
# C:\Users\Vaish\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\Users\Vaish\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %% [markdown]
# #### .head() shows the first few rows of the data so you can see how it starts

# %%
df_long.head()
# Out:
#    Year Month  Value
# 0  2015   Jan  126.0
# 1  2016   Jan  117.8
# 2  2017   Jan  122.3
# 3  2018   Jan  126.5
# 4  2019   Jan  124.6

# %% [markdown]
# ####  .describe() shows basic statistics like the average, minimum, and maximum for the numeric columns

# %%
df_long.describe()
# Out:
#               Year       Value
# count   132.000000  128.000000
# mean   2020.000000  130.785937
# std       3.174324    8.864623
# min    2015.000000  117.200000
# 25%    2017.000000  123.375000
# 50%    2020.000000  126.800000
# 75%    2023.000000  140.350000
# max    2025.000000  148.500000

# %% [markdown]
# #### .info() gives a quick summary of the whole dataset, including missing values

# %%
df_long.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132 entries, 0 to 131
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Year    132 non-null    int64
#  1   Month   132 non-null    object
#  2   Value   128 non-null    float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 3.2+ KB

# %% [markdown]
# #### .sample() gives a random row from the dataset to get a quick look at different values

# %%
df_long.sample()
# Out:
#     Year Month  Value
# 44  2015   May  126.5

# %% [markdown]
# #### .shape tells you how many rows and columns the dataset has

# %%
df_long.shape
# Out:
# (132, 3)

# %% [markdown]
# #### .columns lists all the column names in the dataset

# %%
df_long.columns
# Out:
# Index(['Year', 'Month', 'Value'], dtype='object')

# %% [markdown]
# #### .dtypes shows what type of data each column contains (numbers, text, etc.)

# %%
df_long.dtypes
# Out:
# Year       int64
# Month     object
# Value    float64
# dtype: object

# %% [markdown]
# #### .tail() shows the last few rows of the data to see how it ends

# %%
df_long.tail()
# Out:
#      Year Month  Value
# 127  2021   Dec  137.4
# 128  2022   Dec  141.8
# 129  2023   Dec  138.4
# 130  2024   Dec  141.4
# 131  2025   Dec    NaN

# %%
df_long.to_csv("import_all_commodities.csv", index=False)
